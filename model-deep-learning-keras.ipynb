# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %%
# 4 possibilidade em uma porta XOR
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# 4 resultados esperados, na mesma ordem
target_data = np.array([[0],[1],[1],[0]], "float32")

# %%
model = Sequential()
l1 = Dense(16, input_dim=2, activation='relu')
model.add(l1)
l2 = Dense(1, activation='sigmoid')
model.add(l2)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])
model.fit(training_data, target_data, epochs=500, verbose=2)
print (model.predict(training_data).round())
# Out:
# Epoch 1/500
# 0s - loss: 0.2468 - binary_accuracy: 0.5000
# Epoch 2/500
# 0s - loss: 0.2464 - binary_accuracy: 0.2500
# Epoch 3/500
# 0s - loss: 0.2460 - binary_accuracy: 0.5000
# Epoch 4/500
# 0s - loss: 0.2455 - binary_accuracy: 0.5000
# Epoch 5/500
# 0s - loss: 0.2451 - binary_accuracy: 0.5000
# Epoch 6/500
# 0s - loss: 0.2447 - binary_accuracy: 0.5000
# Epoch 7/500
# 0s - loss: 0.2443 - binary_accuracy: 0.5000
# Epoch 8/500
# 0s - loss: 0.2439 - binary_accuracy: 0.5000
# Epoch 9/500
# 0s - loss: 0.2435 - binary_accuracy: 0.5000
# Epoch 10/500
# 0s - loss: 0.2432 - binary_accuracy: 0.5000
# Epoch 11/500
# 0s - loss: 0.2428 - binary_accuracy: 0.5000
# Epoch 12/500
# 0s - loss: 0.2424 - binary_accuracy: 0.5000
# Epoch 13/500
# 0s - loss: 0.2420 - binary_accuracy: 0.5000
# Epoch 14/500
# 0s - loss: 0.2416 - binary_accuracy: 0.5000
# Epoch 15/500
# 0s - loss: 0.2412 - binary_accuracy: 0.5000
# Epoch 16/500
# 0s - loss: 0.2408 - binary_accuracy: 0.5000
# Epoch 17/500
# ...

# %%
#Executar e analisar:
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)
model.fit(X, y, batch_size=1, epochs=1000)
print(model.predict_proba(X))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s - loss: 0.8021
# Epoch 2/1000
# 4/4 [==============================] - 0s - loss: 0.7848
# Epoch 3/1000
# 4/4 [==============================] - 0s - loss: 0.7732
# Epoch 4/1000
# 4/4 [==============================] - 0s - loss: 0.7666
# Epoch 5/1000
# 4/4 [==============================] - 0s - loss: 0.7566
# Epoch 6/1000
# 4/4 [==============================] - 0s - loss: 0.7545
# Epoch 7/1000
# 4/4 [==============================] - 0s - loss: 0.7506
# Epoch 8/1000
# 4/4 [==============================] - 0s - loss: 0.7467
# Epoch 9/1000
# 4/4 [==============================] - 0s - loss: 0.7420
# Epoch 10/1000
# 4/4 [==============================] - 0s - loss: 0.7371
# Epoch 11/1000
# 4/4 [==============================] - 0s - loss: 0.7364
# Epoch 12/1000
# 4/4 [==============================] - 0s - loss: 0.7320
# Epoch 13/1000
# 4/4 [==============================] - 0s - loss: 0.7316
# Epoch 14/1000
# ...

# %% [markdown]
# Para maiores detalhes: [Keras Examples Mnist](https://github.com/fchollet/keras/blob/master/examples/mnist_mlp.py)
